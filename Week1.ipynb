# %% [markdown]
# <a href="https://colab.research.google.com/github/HanifAjiPrasetyo/PCVK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt


urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print('Resolusi image : tinggi x lebar = ', tinggi, ' x ', lebar)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>
# Resolusi image : tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Horizontal
# for y in range (lebar) :
#   image_3[int((tinggi) / 2), int(y / 3)] = [255,255,255]

# Vertikal
# for x in range (tinggi) :
#   image_3[x, int((lebar) / 2)] = [255,255,255]

# Diagonal
# cv.line(image_3, (0, 0), (lebar, tinggi), [255,255,2555], 1)
# cv.line(image_3, (0, tinggi), (lebar, 0), [255,255,2555], 1)

# Membuat Garis dengan Panjang Tertentu di Tengah Gambar
# panjang_garis = 150
# warna_garis = [255, 255, 255]
# ketebalan_garis = 2
# titik_awal = (int((lebar - panjang_garis) / 2), tinggi // 2)
# titik_akhir = (int((lebar + panjang_garis) / 2), tinggi // 2)
# cv.line(image_3, titik_awal, titik_akhir, warna_garis, ketebalan_garis)

# Buat Kotak di Sembarang Tempat
warna_kotak = [255, 255, 255]
pojok_kiri_atas = (100, 100)
pojok_kanan_bawah = (200, 200)
cv.rectangle(image_3, pojok_kiri_atas, pojok_kanan_bawah, warna_kotak, -1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
ktp = cv.imread('KTP.jpeg')

ktp_rgb = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)

kuning = [250, 208, 92]
hitam = [0,0,0]
putih = [250,250,250]
hijau = [6, 150, 59]
biru = [3, 16, 133]
merah = [255, 71, 71]

# Kelompok 1 (NIK dan Nama)

# koordinats = [(185, 65, 550, 100), (190, 115, 480, 140)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = kuning
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = hitam


# Kelompok 2 (TTL dan JK)

# koordinats = [(190, 140, 460, 160), (190, 165, 300, 185)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = hijau
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = merah


# Kelompok 3 (Gol. Darah dan TTD)

# koordinats = [(380, 165, 550, 183), (605, 400, 760, 500)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = biru
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = merah


# Kelompok 4 (Alamat dan Kecamatan)

# koordinats = [(190, 188, 400, 208), (190, 258, 300, 278)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = putih
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = hitam


# Kelompok 5 (Agama dan Status Kawin)

# koordinats = [(190, 280, 300, 300), (190, 305, 300, 325)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = merah
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = kuning


# Kelompok 6 (Pekerjaan dan Kewarganegaraan)

# koordinats = [(190, 327, 480, 347), (190, 351, 250, 371)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = biru
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = putih


# Kelompok 7 (Berlaku Hingga dan Foto)

# koordinats = [(190, 375, 350, 395), (570, 85, 770, 330)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = hijau
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = biru


# Kelompok 8 (Kabupaten Bawah dan Tanggal KTP)

# koordinats = [(630, 340, 730, 360), (630, 365, 730, 385)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = hitam
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = hijau


# Kelompok 9 (Provinsi dan Kabupaten Atas)

# koordinats = [(213, 5, 600, 30), (260, 34, 552, 59)]
# ktp_processed = ktp_rgb.copy()
# x1, y1, x2, y2 = koordinats[0]
# ktp_processed[y1:y2, x1:x2] = biru
# x1, y1, x2, y2 = koordinats[1]
# ktp_processed[y1:y2, x1:x2] = kuning


# Kelompok 10 (RT/RW dan Kel/Desa)

koordinats = [(190, 212, 280, 232), (190, 235, 260, 255)]
ktp_processed = ktp_rgb.copy()
x1, y1, x2, y2 = koordinats[0]
ktp_processed[y1:y2, x1:x2] = hijau
x1, y1, x2, y2 = koordinats[1]
ktp_processed[y1:y2, x1:x2] = putih

plt.imshow(ktp_processed)
plt.axis('off')
plt.show()
